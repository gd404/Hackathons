# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score
import category_encoders as ce
from pycaret.classification import setup
from pycaret.classification import compare_models, tune_model, create_model
# %matplotlib inline

# %%
df_train = pd.read_csv('train_Df64byy.csv')
df_train['type'] = 'train'
df_test = pd.read_csv('test_YCcRUnU.csv')
df_test['type'] = 'test'
df = pd.concat([df_train, df_test], axis = 0)
df.head(10)
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
# 5   6        C9         1785            Rented          Individual         52
# 6   7        C3          679             Owned          Individual         28
# 7   8        C1         3175             Owned               Joint         75
# 8   9       C15         3497             Owned               Joint         52
# 9  10        C1          530             Owned               Joint         59
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
# 5         52        No               X2                     5.0
# 6         28        No              NaN                     NaN
# 7         73       Yes               X4                     9.0
# 8         43        No               X1                    14.0
# 9         26       Yes              NaN                     7.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response   type
# 0                  3.0               22              11628.0       0.0  train
# 1                  NaN               22              30510.0       0.0  train
# 2                  1.0               19               7450.0       1.0  train
# 3                  3.0               19              17780.0       0.0  train
# 4                  1.0               16              10404.0       0.0  train
# 5                  1.0               22              15264.0       1.0  train
# 6                  NaN               17              10640.0       0.0  train
# 7                  4.0               17              29344.0       1.0  train
# 8                  3.0                1              27283.2       0.0  train
# 9                  4.0               18              21100.8       1.0  train

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72687 entries, 0 to 21804
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       72687 non-null  int64
#  1   City_Code                72687 non-null  object
#  2   Region_Code              72687 non-null  int64
#  3   Accomodation_Type        72687 non-null  object
#  4   Reco_Insurance_Type      72687 non-null  object
#  5   Upper_Age                72687 non-null  int64
#  6   Lower_Age                72687 non-null  int64
#  7   Is_Spouse                72687 non-null  object
#  8   Health Indicator         55969 non-null  object
#  9   Holding_Policy_Duration  43833 non-null  object
#  10  Holding_Policy_Type      43833 non-null  float64
#  11  Reco_Policy_Cat          72687 non-null  int64
#  12  Reco_Policy_Premium      72687 non-null  float64
#  13  Response                 50882 non-null  float64
#  14  type                     72687 non-null  object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 8.9+ MB

# %%
cols = df.columns
for i in cols:
    print(i, 'has', df[i].nunique(), 'unique values')
# Out:
# ID has 72687 unique values
# City_Code has 36 unique values
# Region_Code has 5538 unique values
# Accomodation_Type has 2 unique values
# Reco_Insurance_Type has 2 unique values
# Upper_Age has 58 unique values
# Lower_Age has 60 unique values
# Is_Spouse has 2 unique values
# Health Indicator has 9 unique values
# Holding_Policy_Duration has 15 unique values
# Holding_Policy_Type has 4 unique values
# Reco_Policy_Cat has 22 unique values
# Reco_Policy_Premium has 7685 unique values
# Response has 2 unique values
# type has 2 unique values

# %%
for i in df.columns:
    print('Value Counts for', i)
    print(df[i].value_counts())
# Out:
# Value Counts for ID
# 2047     1
# 661      1
# 53903    1
# 10896    1
# 8849     1
#         ..
# 17762    1
# 23905    1
# 21856    1
# 68939    1
# 2049     1
# Name: ID, Length: 72687, dtype: int64
# Value Counts for City_Code
# C1     12762
# C2     11078
# C3      6954
# C4      5230
# C9      3089
# C6      2769
# C7      2698
# C8      2579
# C10     2291
# C5      1963
# C17     1689
# C15     1663
# C11     1661
# C16     1613
# C13     1429
# C20     1370
# C12     1310
# C19     1264
# C18     1131
# C14     1089
# C21      984
# C23      842
# C24      823
# C26      731
# C22      713
# C25      536
# C29      533
# C27      437
# C28      394
# C33      392
# C32      240
# C34      189
# C35       89
# C30       81
# C36       54
# C31       17
# Name: City_Code, dtype: int64
# Value Counts for Region_Code
# 1       140
# 2       112
# 5       105
# 6       102
# 4       102
#        ...
# 5619      1
# 5631      1
# 5615      1
# 5740      1
# 5750      1
# Name: Region_Code, Length: 5538, dtype: int64
# Value Counts for Accomodation_Type
# Owned     40041
# Rented    32646
# Name: Accomodation_Type, dtype: int64
# Value Counts for Reco_Insurance_Type
# Individual    57877
# Joint         14810
# Name: Reco_Insurance_Type, dtype: int64
# Value Counts for Upper_Age
# 75    4231
# 24    2374
# 23    2365
# 25    2346
# 22    2214
# 26    2045
# 27    1750
# 28    1703
# 21    1601
# 29    1410
# 30    1389
# 31    1286
# 32    1272
# 55    1259
# 52    1229
# 48    1197
# 43    1197
# 46    1188
# 58    1184
# 42    1179
# 33    1177
# 56    1172
# 53    1164
# 54    1163
# 34    1162
# 35    1154
# 51    1148
# 50    1143
# 44    1139
# 49    1137
# 45    1134
# 20    1133
# 59    1130
# 57    1122
# 41    1119
# 47    1116
# 65    1108
# 60    1091
# 61    1081
# 63    1078
# 66    1075
# 36    1066
# 38    1065
# 37    1061
# 64    1049
# 40    1040
# 62    1036
# 39    1005
# 70     964
# 69     855
# 67     845
# 68     793
# 71     790
# 19     732
# 72     708
# 73     685
# 74     654
# 18     174
# Name: Upper_Age, dtype: int64
# Value Counts for Lower_Age
# 75    3143
# 23    2619
# 25    2553
# 24    2546
# 22    2442
# 26    2188
# 27    1903
# 21    1901
# 28    1848
# 29    1543
# 30    1462
# 20    1459
# 31    1381
# 32    1355
# 33    1261
# 35    1211
# 34    1203
# 55    1191
# 52    1136
# 48    1120
# 46    1108
# 42    1103
# 58    1103
# 43    1092
# 19    1091
# 50    1091
# 53    1086
# 56    1073
# 36    1066
# 51    1065
# 65    1064
# 57    1059
# 37    1057
# 49    1053
# 45    1051
# 38    1051
# 44    1051
# 47    1047
# 54    1047
# 41    1046
# 59    1029
# 60    1024
# 40    1023
# 62    1013
# 66    1006
# 61     998
# 39     992
# 64     985
# 63     959
# 70     840
# 69     784
# 68     751
# 67     716
# 71     713
# 72     605
# 73     599
# 74     584
# 18     519
# 16     388
# 17     290
# Name: Lower_Age, dtype: int64
# Value Counts for Is_Spouse
# No     60687
# Yes    12000
# Name: Is_Spouse, dtype: int64
# Value Counts for Health Indicator
# X1    18624
# X2    14848
# X3     9608
# X4     8185
# X5     2408
# X6     1794
# X7      292
# X8      119
# X9       91
# Name: Health Indicator, dtype: int64
# Value Counts for Holding_Policy_Duration
# 1.0     6390
# 14+     6227
# 2.0     6032
# 3.0     5192
# 4.0     3976
# 5.0     3354
# 6.0     2797
# 7.0     2309
# 8.0     1885
# 9.0     1607
# 10.0    1146
# 11.0     800
# 13.0     732
# 12.0     709
# 14.0     677
# Name: Holding_Policy_Duration, dtype: int64
# Value Counts for Holding_Policy_Type
# 3.0    18851
# 1.0    11747
# 2.0     7155
# 4.0     6080
# Name: Holding_Policy_Type, dtype: int64
# Value Counts for Reco_Policy_Cat
# 22    9459
# 18    7890
# 21    7161
# 16    5786
# 17    5445
# 19    5319
# 20    4511
# 12    3127
# 1     2775
# 2     2677
# 14    2512
# 13    2441
# 15    2256
# 3     1550
# 4     1464
# 5     1453
# 6     1181
# 7     1151
# 8     1150
# 9     1146
# 10    1123
# 11    1110
# Name: Reco_Policy_Cat, dtype: int64
# Value Counts for Reco_Policy_Premium
# 10800.0    92
# 10368.0    88
# 10080.0    85
# 12060.0    82
# 11880.0    82
#            ..
# 25843.2     1
# 7283.2      1
# 9495.0      1
# 11155.2     1
# 17955.0     1
# Name: Reco_Policy_Premium, Length: 7685, dtype: int64
# Value Counts for Response
# 0.0    38673
# 1.0    12209
# Name: Response, dtype: int64
# Value Counts for type
# train    50882
# test     21805
# Name: type, dtype: int64

# %%
sns.barplot(x = 'Reco_Policy_Cat', y = 'Reco_Policy_Premium', data = df)

# %%
sns.heatmap(df.isnull())

# %%
hh = df['Health Indicator'].unique()
for i in hh:
    print('Value Counts for', i)
    print(df[df['Health Indicator'] == i]['Response'].value_counts())
# Out:
# Value Counts for X1
# 0.0    9834
# 1.0    3176
# Name: Response, dtype: int64
# Value Counts for X2
# 0.0    7841
# 1.0    2491
# Name: Response, dtype: int64
# Value Counts for nan
# Series([], Name: Response, dtype: int64)
# Value Counts for X4
# 0.0    4347
# 1.0    1396
# Name: Response, dtype: int64
# Value Counts for X3
# 0.0    5163
# 1.0    1599
# Name: Response, dtype: int64
# Value Counts for X6
# 0.0    973
# 1.0    307
# Name: Response, dtype: int64
# Value Counts for X5
# 0.0    1319
# 1.0     408
# Name: Response, dtype: int64
# Value Counts for X8
# 0.0    60
# 1.0    18
# Name: Response, dtype: int64
# Value Counts for X7
# 0.0    134
# 1.0     62
# Name: Response, dtype: int64
# Value Counts for X9
# 0.0    49
# 1.0    14
# Name: Response, dtype: int64

# %%
ll = ['X8', 'X7', 'X9']
for i in ll:
    print(len(df[df['Health Indicator'] == i]))
# Out:
# 119
# 292
# 91

# %% [markdown]
# # Handling Missing Vars

# %%
df['Holding_Policy_Duration'].fillna('0', inplace = True)
# sns.heatmap(df.isnull())

# %%
df['Holding_Policy_Type'].fillna(0.0, inplace = True)

# %%
# Imputing health indicator to X1, we will check later
df['Health Indicator'].fillna('X0', inplace = True)

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# # One-Hot Encoding cat vars

# %%
# dummies = pd.get_dummies(data = df, columns = ['Accomodation_Type', 'Reco_Insurance_Type', 'Is_Spouse', 'Holding_Policy_Type'])
dummies = pd.get_dummies(data = df, columns = ['Accomodation_Type', 'Reco_Insurance_Type'], drop_first = True)
dummies
# Out:
#           ID City_Code  Region_Code  Upper_Age  Lower_Age Is_Spouse  \
# 0          1        C3         3213         36         36        No
# 1          2        C5         1117         75         22        No
# 2          3        C5         3732         32         32        No
# 3          4       C24         4378         52         48        No
# 4          5        C8         2190         44         44        No
# ...      ...       ...          ...        ...        ...       ...
# 21800  72683        C3         1044         45         45        No
# 21801  72684        C4          266         59         59        No
# 21802  72685       C12         2470         74         74        No
# 21803  72686       C10         1676         25         25        No
# 21804  72687        C2         3617         73         73        No
#
#       Health Indicator Holding_Policy_Duration  Holding_Policy_Type  \
# 0                   X1                     14+                  3.0
# 1                   X2                       0                  0.0
# 2                   X0                     1.0                  1.0
# 3                   X1                     14+                  3.0
# 4                   X2                     3.0                  1.0
# ...                ...                     ...                  ...
# 21800               X1                     4.0                  1.0
# 21801               X5                     6.0                  3.0
# 21802               X3                       0                  0.0
# 21803               X4                     3.0                  1.0
# 21804               X2                     14+                  2.0
#
#        Reco_Policy_Cat  Reco_Policy_Premium  Response   type  \
# 0                   22              11628.0       0.0  train
# 1                   22              30510.0       0.0  train
# 2                   19               7450.0       1.0  train
# 3                   19              17780.0       0.0  train
# 4                   16              10404.0       0.0  train
# ...                ...                  ...       ...    ...
# 21800               18              15884.0       NaN   test
# 21801               18              21390.0       NaN   test
# 21802                1              17836.0       NaN   test
# 21803               19              11568.0       NaN   test
# 21804                3              23040.0       NaN   test
#
#        Accomodation_Type_Rented  Reco_Insurance_Type_Joint
# 0                             1                          0
# 1                             0                          1
# 2                             0                          0
# 3                             0                          1
# 4                             1                          0
# ...                         ...                        ...
# 21800                         0                          0
# 21801                         0                          0
# 21802                         0                          0
# 21803                         1                          0
# 21804                         0                          0
#
# [72687 rows x 15 columns]

# %% [markdown]
# # Merging Upper and Lower Age

# %%
dummies['Age'] = (dummies['Upper_Age'] + dummies['Lower_Age'])/2
dummies.drop(['Upper_Age', 'Lower_Age'], axis = 1, inplace = True)
dummies
# Out:
#           ID City_Code  Region_Code Is_Spouse Health Indicator  \
# 0          1        C3         3213        No               X1
# 1          2        C5         1117        No               X2
# 2          3        C5         3732        No               X0
# 3          4       C24         4378        No               X1
# 4          5        C8         2190        No               X2
# ...      ...       ...          ...       ...              ...
# 21800  72683        C3         1044        No               X1
# 21801  72684        C4          266        No               X5
# 21802  72685       C12         2470        No               X3
# 21803  72686       C10         1676        No               X4
# 21804  72687        C2         3617        No               X2
#
#       Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 0                         14+                  3.0               22
# 1                           0                  0.0               22
# 2                         1.0                  1.0               19
# 3                         14+                  3.0               19
# 4                         3.0                  1.0               16
# ...                       ...                  ...              ...
# 21800                     4.0                  1.0               18
# 21801                     6.0                  3.0               18
# 21802                       0                  0.0                1
# 21803                     3.0                  1.0               19
# 21804                     14+                  2.0                3
#
#        Reco_Policy_Premium  Response   type  Accomodation_Type_Rented  \
# 0                  11628.0       0.0  train                         1
# 1                  30510.0       0.0  train                         0
# 2                   7450.0       1.0  train                         0
# 3                  17780.0       0.0  train                         0
# 4                  10404.0       0.0  train                         1
# ...                    ...       ...    ...                       ...
# 21800              15884.0       NaN   test                         0
# 21801              21390.0       NaN   test                         0
# 21802              17836.0       NaN   test                         0
# 21803              11568.0       NaN   test                         1
# 21804              23040.0       NaN   test                         0
#
#        Reco_Insurance_Type_Joint   Age
# 0                              0  36.0
# 1                              1  48.5
# 2                              0  32.0
# 3                              1  50.0
# 4                              0  44.0
# ...                          ...   ...
# 21800                          0  45.0
# 21801                          0  59.0
# 21802                          0  74.0
# 21803                          0  25.0
# 21804                          0  73.0
#
# [72687 rows x 14 columns]

# %% [markdown]
# # Changing Holding_Policy_Value 14+ to 15 and converting the column into int

# %%
dummies['Holding_Policy_Duration'] = dummies['Holding_Policy_Duration'].apply(lambda x: 15 if x == '14+' else float(x))
dummies['Holding_Policy_Duration'] = dummies['Holding_Policy_Duration'].apply(lambda x: float(x))

# %%
dummies.dtypes
# Out:
# ID                             int64
# City_Code                     object
# Region_Code                    int64
# Is_Spouse                     object
# Health Indicator              object
# Holding_Policy_Duration      float64
# Holding_Policy_Type          float64
# Reco_Policy_Cat                int64
# Reco_Policy_Premium          float64
# Response                     float64
# type                          object
# Accomodation_Type_Rented       uint8
# Reco_Insurance_Type_Joint      uint8
# Age                          float64
# dtype: object

# %% [markdown]
# # Converting Is_Spouse to numerical

# %%
dummies['Is_Spouse'] = dummies['Is_Spouse'].map({'No': 0, 'Yes': 1})
dummies
# Out:
#           ID City_Code  Region_Code  Is_Spouse Health Indicator  \
# 0          1        C3         3213          0               X1
# 1          2        C5         1117          0               X2
# 2          3        C5         3732          0               X0
# 3          4       C24         4378          0               X1
# 4          5        C8         2190          0               X2
# ...      ...       ...          ...        ...              ...
# 21800  72683        C3         1044          0               X1
# 21801  72684        C4          266          0               X5
# 21802  72685       C12         2470          0               X3
# 21803  72686       C10         1676          0               X4
# 21804  72687        C2         3617          0               X2
#
#        Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 0                         15.0                  3.0               22
# 1                          0.0                  0.0               22
# 2                          1.0                  1.0               19
# 3                         15.0                  3.0               19
# 4                          3.0                  1.0               16
# ...                        ...                  ...              ...
# 21800                      4.0                  1.0               18
# 21801                      6.0                  3.0               18
# 21802                      0.0                  0.0                1
# 21803                      3.0                  1.0               19
# 21804                     15.0                  2.0                3
#
#        Reco_Policy_Premium  Response   type  Accomodation_Type_Rented  \
# 0                  11628.0       0.0  train                         1
# 1                  30510.0       0.0  train                         0
# 2                   7450.0       1.0  train                         0
# 3                  17780.0       0.0  train                         0
# 4                  10404.0       0.0  train                         1
# ...                    ...       ...    ...                       ...
# 21800              15884.0       NaN   test                         0
# 21801              21390.0       NaN   test                         0
# 21802              17836.0       NaN   test                         0
# 21803              11568.0       NaN   test                         1
# 21804              23040.0       NaN   test                         0
#
#        Reco_Insurance_Type_Joint   Age
# 0                              0  36.0
# 1                              1  48.5
# 2                              0  32.0
# 3                              1  50.0
# 4                              0  44.0
# ...                          ...   ...
# 21800                          0  45.0
# 21801                          0  59.0
# 21802                          0  74.0
# 21803                          0  25.0
# 21804                          0  73.0
#
# [72687 rows x 14 columns]

# %% [markdown]
# # Converting Health Indicator using One-Hot Encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
dummies = pd.get_dummies(dummies, columns = ['Health Indicator'])
dummies
# Out:
#           ID City_Code  Region_Code  Is_Spouse  Holding_Policy_Duration  \
# 0          1        C3         3213          0                     15.0
# 1          2        C5         1117          0                      0.0
# 2          3        C5         3732          0                      1.0
# 3          4       C24         4378          0                     15.0
# 4          5        C8         2190          0                      3.0
# ...      ...       ...          ...        ...                      ...
# 21800  72683        C3         1044          0                      4.0
# 21801  72684        C4          266          0                      6.0
# 21802  72685       C12         2470          0                      0.0
# 21803  72686       C10         1676          0                      3.0
# 21804  72687        C2         3617          0                     15.0
#
#        Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response  \
# 0                      3.0               22              11628.0       0.0
# 1                      0.0               22              30510.0       0.0
# 2                      1.0               19               7450.0       1.0
# 3                      3.0               19              17780.0       0.0
# 4                      1.0               16              10404.0       0.0
# ...                    ...              ...                  ...       ...
# 21800                  1.0               18              15884.0       NaN
# 21801                  3.0               18              21390.0       NaN
# 21802                  0.0                1              17836.0       NaN
# 21803                  1.0               19              11568.0       NaN
# 21804                  2.0                3              23040.0       NaN
#
#         type  Accomodation_Type_Rented  Reco_Insurance_Type_Joint   Age  \
# 0      train                         1                          0  36.0
# 1      train                         0                          1  48.5
# 2      train                         0                          0  32.0
# 3      train                         0                          1  50.0
# 4      train                         1                          0  44.0
# ...      ...                       ...                        ...   ...
# 21800   test                         0                          0  45.0
# 21801   test                         0                          0  59.0
# 21802   test                         0                          0  74.0
# 21803   test                         1                          0  25.0
# 21804   test                         0                          0  73.0
#
#        Health Indicator_X0  Health Indicator_X1  Health Indicator_X2  \
# 0                        0                    1                    0
# 1                        0                    0                    1
# 2                        1                    0                    0
# 3                        0                    1                    0
# 4                        0                    0                    1
# ...                    ...                  ...                  ...
# 21800                    0                    1                    0
# 21801                    0                    0                    0
# 21802                    0                    0                    0
# 21803                    0                    0                    0
# 21804                    0                    0                    1
#
#        Health Indicator_X3  Health Indicator_X4  Health Indicator_X5  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# 2                        0                    0                    0
# 3                        0                    0                    0
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 21800                    0                    0                    0
# 21801                    0                    0                    1
# 21802                    1                    0                    0
# 21803                    0                    1                    0
# 21804                    0                    0                    0
#
#        Health Indicator_X6  Health Indicator_X7  Health Indicator_X8  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# 2                        0                    0                    0
# 3                        0                    0                    0
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 21800                    0                    0                    0
# 21801                    0                    0                    0
# 21802                    0                    0                    0
# 21803                    0                    0                    0
# 21804                    0                    0                    0
#
#        Health Indicator_X9
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 21800                    0
# 21801                    0
# 21802                    0
# 21803                    0
# 21804                    0
#
# [72687 rows x 23 columns]

# %%
dummies.dtypes
# Out:
# ID                             int64
# City_Code                     object
# Region_Code                    int64
# Is_Spouse                      int64
# Holding_Policy_Duration      float64
# Holding_Policy_Type          float64
# Reco_Policy_Cat                int64
# Reco_Policy_Premium          float64
# Response                     float64
# type                          object
# Accomodation_Type_Rented       uint8
# Reco_Insurance_Type_Joint      uint8
# Age                          float64
# Health Indicator_X0            uint8
# Health Indicator_X1            uint8
# Health Indicator_X2            uint8
# Health Indicator_X3            uint8
# Health Indicator_X4            uint8
# Health Indicator_X5            uint8
# Health Indicator_X6            uint8
# Health Indicator_X7            uint8
# Health Indicator_X8            uint8
# Health Indicator_X9            uint8
# dtype: object

# %%
df['City_Code'].value_counts()
# Out:
# C1     12762
# C2     11078
# C3      6954
# C4      5230
# C9      3089
# C6      2769
# C7      2698
# C8      2579
# C10     2291
# C5      1963
# C17     1689
# C15     1663
# C11     1661
# C16     1613
# C13     1429
# C20     1370
# C12     1310
# C19     1264
# C18     1131
# C14     1089
# C21      984
# C23      842
# C24      823
# C26      731
# C22      713
# C25      536
# C29      533
# C27      437
# C28      394
# C33      392
# C32      240
# C34      189
# C35       89
# C30       81
# C36       54
# C31       17
# Name: City_Code, dtype: int64

# %% [markdown]
# # Using HASH Encoder for City Code

# %%
lbl2 = LabelEncoder()
city = lbl2.fit_transform(dummies['City_Code'])
dummies['City_Code'] = city
data = dummies

# %%
# hash_encoder = ce.HashingEncoder(cols = ['City_Code'], drop_invariant=True)
# data = hash_encoder.fit_transform(dummies)
# data

# %%
data.dtypes
# Out:
# ID                             int64
# City_Code                      int32
# Region_Code                    int64
# Is_Spouse                      int64
# Holding_Policy_Duration      float64
# Holding_Policy_Type          float64
# Reco_Policy_Cat                int64
# Reco_Policy_Premium          float64
# Response                     float64
# type                          object
# Accomodation_Type_Rented       uint8
# Reco_Insurance_Type_Joint      uint8
# Age                          float64
# Health Indicator_X0            uint8
# Health Indicator_X1            uint8
# Health Indicator_X2            uint8
# Health Indicator_X3            uint8
# Health Indicator_X4            uint8
# Health Indicator_X5            uint8
# Health Indicator_X6            uint8
# Health Indicator_X7            uint8
# Health Indicator_X8            uint8
# Health Indicator_X9            uint8
# dtype: object

# %% [markdown]
# # Separating train and test data

# %%
train_set = data[data['type'] == 'train']
train_set.drop(['type', 'ID'], axis = 1, inplace = True)
test_set = data[data['type'] == 'test']
test_set.drop(['type', 'ID'], axis = 1, inplace = True)

# %%
len(train_set), len(test_set)
# Out:
# (50882, 21805)

# %%
train_set.dtypes
# Out:
# City_Code                      int32
# Region_Code                    int64
# Is_Spouse                      int64
# Holding_Policy_Duration      float64
# Holding_Policy_Type          float64
# Reco_Policy_Cat                int64
# Reco_Policy_Premium          float64
# Response                     float64
# Accomodation_Type_Rented       uint8
# Reco_Insurance_Type_Joint      uint8
# Age                          float64
# Health Indicator_X0            uint8
# Health Indicator_X1            uint8
# Health Indicator_X2            uint8
# Health Indicator_X3            uint8
# Health Indicator_X4            uint8
# Health Indicator_X5            uint8
# Health Indicator_X6            uint8
# Health Indicator_X7            uint8
# Health Indicator_X8            uint8
# Health Indicator_X9            uint8
# dtype: object

# %%
type(train_set[['Response']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Building Model

# %%
# Using City and Region Code
X = train_set.drop(['Response'], axis = 1)
y = train_set['Response']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=46)

# %%
import xgboost as xgb
model = xgb.XGBClassifier(random_state=101,learning_rate=0.01)
model.fit(X_train, y_train)
model.score(X_test,y_test)
# Out:
# [11:05:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.7577871671415938

# %%
len(model.feature_importances_)
# Out:
# 20

# %%
model.feature_importances_
# Out:
# array([6.1392546e-02, 4.2897724e-02, 2.3577308e-02, 6.7210436e-02,
#        8.5637301e-02, 4.2513752e-01, 1.8932039e-02, 5.9186634e-02,
#        1.0271736e-02, 2.7991064e-02, 2.6937490e-02, 1.2640890e-02,
#        3.6305636e-02, 1.4805166e-02, 2.6820133e-02, 2.1931890e-02,
#        9.8896576e-03, 2.8286926e-02, 1.4797793e-04, 0.0000000e+00],
#       dtype=float32)

# %%
xgb.plot_importance(model)

# %% [markdown]
# # PyCaret

# %%
grid = setup(data = train_set, target = 'Response')
# Out:
# <style  type="text/css" >
# </style><table id="T_c0545478_7986_11eb_82e7_c85b7634790f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow0_col1" class="data row0 col1" >1283</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow1_col1" class="data row1 col1" >Response</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow3_col1" class="data row3 col1" >0.0: 0, 1.0: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow4_col1" class="data row4 col1" >(50882, 21)</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow6_col1" class="data row6 col1" >19</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow7_col1" class="data row7 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow11_col1" class="data row11 col1" >(35617, 20)</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow12_col1" class="data row12 col1" >(15265, 20)</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_c0545478_7986_11eb_82e7_c85b7634790flevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_c0545478_7986_11eb_82e7_c85b7634790frow18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_24543b70_7987_11eb_a686_c85b7634790f th {
#           text-align: left;
#     }    #T_24543b70_7987_11eb_a686_c85b7634790frow0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow0_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow0_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow0_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow0_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow0_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow1_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow1_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow1_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow1_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow1_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow1_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow1_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow1_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow1_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow2_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow2_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow2_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow2_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow2_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow2_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow2_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow2_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow2_col8 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow3_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow3_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow3_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow3_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow3_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow3_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow3_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow3_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow3_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow4_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow4_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow4_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow4_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow4_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow4_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow4_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow4_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow4_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow5_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow5_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow5_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow5_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow5_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow5_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow5_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow5_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_24543b70_7987_11eb_a686_c85b7634790frow5_col8 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-colo
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=1283, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
lgbm = create_model('lightgbm')
# Out:
# <style  type="text/css" >
#     #T_eb21303a_7991_11eb_a536_c85b7634790frow10_col0 {
#             background:  yellow;
#         }    #T_eb21303a_7991_11eb_a536_c85b7634790frow10_col1 {
#             background:  yellow;
#         }    #T_eb21303a_7991_11eb_a536_c85b7634790frow10_col2 {
#             background:  yellow;
#         }    #T_eb21303a_7991_11eb_a536_c85b7634790frow10_col3 {
#             background:  yellow;
#         }    #T_eb21303a_7991_11eb_a536_c85b7634790frow10_col4 {
#             background:  yellow;
#         }    #T_eb21303a_7991_11eb_a536_c85b7634790frow10_col5 {
#             background:  yellow;
#         }    #T_eb21303a_7991_11eb_a536_c85b7634790frow10_col6 {
#             background:  yellow;
#         }</style><table id="T_eb21303a_7991_11eb_a536_c85b7634790f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eb21303a_7991_11eb_a536_c85b7634790flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow0_col0" class="data row0 col0" >0.7600</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow0_col1" class="data row0 col1" >0.6762</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow0_col2" class="data row0 col2" >0.0278</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow0_col3" class="data row0 col3" >0.6000</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow0_col4" class="data row0 col4" >0.0532</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow0_col5" class="data row0 col5" >0.0324</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow0_col6" class="data row0 col6" >0.0890</td>
#             </tr>
#             <tr>
#                         <th id="T_eb21303a_7991_11eb_a536_c85b7634790flevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow1_col0" class="data row1 col0" >0.7614</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow1_col1" class="data row1 col1" >0.6701</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow1_col2" class="data row1 col2" >0.0301</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow1_col3" class="data row1 col3" >0.6667</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow1_col4" class="data row1 col4" >0.0576</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow1_col5" class="data row1 col5" >0.0375</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow1_col6" class="data row1 col6" >0.1042</td>
#             </tr>
#             <tr>
#                         <th id="T_eb21303a_7991_11eb_a536_c85b7634790flevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow2_col0" class="data row2 col0" >0.7588</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow2_col1" class="data row2 col1" >0.6601</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow2_col2" class="data row2 col2" >0.0209</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow2_col3" class="data row2 col3" >0.5625</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow2_col4" class="data row2 col4" >0.0402</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow2_col5" class="data row2 col5" >0.0233</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow2_col6" class="data row2 col6" >0.0712</td>
#             </tr>
#             <tr>
#                         <th id="T_eb21303a_7991_11eb_a536_c85b7634790flevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow3_col0" class="data row3 col0" >0.7549</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow3_col1" class="data row3 col1" >0.6554</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow3_col2" class="data row3 col2" >0.0116</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow3_col3" class="data row3 col3" >0.3333</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow3_col4" class="data row3 col4" >0.0224</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow3_col5" class="data row3 col5" >0.0062</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow3_col6" class="data row3 col6" >0.0196</td>
#             </tr>
#             <tr>
#                         <th id="T_eb21303a_7991_11eb_a536_c85b7634790flevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow4_col0" class="data row4 col0" >0.7569</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow4_col1" class="data row4 col1" >0.6730</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow4_col2" class="data row4 col2" >0.0209</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow4_col3" class="data row4 col3" >0.4615</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow4_col4" class="data row4 col4" >0.0399</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow4_col5" class="data row4 col5" >0.0194</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow4_col6" class="data row4 col6" >0.0538</td>
#             </tr>
#             <tr>
#                         <th id="T_eb21303a_7991_11eb_a536_c85b7634790flevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow5_col0" class="data row5 col0" >0.7602</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow5_col1" class="data row5 col1" >0.6606</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow5_col2" class="data row5 col2" >0.0290</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow5_col3" class="data row5 col3" >0.6098</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow5_col4" class="data row5 col4" >0.0553</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow5_col5" class="data row5 col5" >0.0341</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow5_col6" class="data row5 col6" >0.0925</td>
#             </tr>
#             <tr>
#                         <th id="T_eb21303a_7991_11eb_a536_c85b7634790flevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow6_col0" class="data row6 col0" >0.7597</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow6_col1" class="data row6 col1" >0.6733</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow6_col2" class="data row6 col2" >0.0220</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow6_col3" class="data row6 col3" >0.6333</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow6_col4" class="data row6 col4" >0.0425</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c85b7634790frow6_col5" class="data row6 col5" >0.0267</td>
#                         <td id="T_eb21303a_7991_11eb_a536_c

# %%
tuned_lightgbm = tune_model('lightgbm')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-bad0fd5f650e> in <module>
# ----> 1 tuned_lightgbm = tune_model('lightgbm')
#
# ~\anaconda3\lib\site-packages\pycaret\classification.py in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, **kwargs)
#    1100         verbose=verbose,
#    1101         tuner_verbose=tuner_verbose,
# -> 1102         **kwargs,
#    1103     )
#    1104
#
# ~\anaconda3\lib\site-packages\pycaret\internal\tabular.py in tune_model_supervised(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, display, **kwargs)
#    3787     if type(estimator) is str:
#    3788         raise TypeError(
# -> 3789             "The behavior of tune_model in version 1.0.1 is changed. Please pass trained model object."
#    3790         )
#    3791
#
# TypeError: The behavior of tune_model in version 1.0.1 is changed. Please pass trained model object.

# %% [markdown]
# # Modelling using above features from feature importance graph

# %%
X = data.drop(['Health Indicator_X4', 'col_3'], axis = 1)
y = data['Response']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
# Striaght model
model=xgb.XGBClassifier(random_state=1,learning_rate=0.01)
model.fit(X_train, y_train)
model.score(X_test,y_test)
# Out:
# [20:16:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 1.0

# %%
# Customized model
dt = xgb.DMatrix(X_train.to_numpy(),label=y_train.to_numpy())
dv = xgb.DMatrix(X_test.to_numpy(),label=y_test.to_numpy())
params = {
    "eta": 0.2,
    "max_depth": 4,
    "objective": "binary:logistic",
    "silent": 1,
    "base_score": np.mean(y_train),
    'n_estimators': 1000,
    "eval_metric": "logloss"
}
model = xgb.train(params, dt, 3000, [(dt, "train"),(dv, "valid")], verbose_eval=200)
# Out:
# [20:16:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { n_estimators, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-logloss:0.37531	valid-logloss:0.37114
# [200]	train-logloss:0.00006	valid-logloss:0.00006
# [400]	train-logloss:0.00006	valid-logloss:0.00006
# [600]	train-logloss:0.00006	valid-logloss:0.00006
# [800]	train-logloss:0.00006	valid-logloss:0.00006
# [1000]	train-logloss:0.00006	valid-logloss:0.00006
# [1200]	train-logloss:0.00006	valid-logloss:0.00006
# [1400]	train-logloss:0.00006	valid-logloss:0.00006
# [1600]	train-logloss:0.00006	valid-logloss:0.00006
# [1800]	train-logloss:0.00006	valid-logloss:0.00006
# [2000]	train-logloss:0.00006	valid-logloss:0.00006
# [2200]	train-logloss:0.00006	valid-logloss:0.00006
# [2400]	train-logloss:0.00006	valid-logloss:0.00006
# [2600]	train-logloss:0.00006	valid-logloss:0.00006
# [2800]	train-logloss:0.00006	valid-logloss:0.00006
# [2999]	train-logloss:0.00006	valid-logloss:0.00006

# %% [markdown]
# # Test Set Preprocessing

# %%
test_df = pd.read_csv('test_YCcRUnU.csv')
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21805 entries, 0 to 21804
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       21805 non-null  int64
#  1   City_Code                21805 non-null  object
#  2   Region_Code              21805 non-null  int64
#  3   Accomodation_Type        21805 non-null  object
#  4   Reco_Insurance_Type      21805 non-null  object
#  5   Upper_Age                21805 non-null  int64
#  6   Lower_Age                21805 non-null  int64
#  7   Is_Spouse                21805 non-null  object
#  8   Health Indicator         16778 non-null  object
#  9   Holding_Policy_Duration  13202 non-null  object
#  10  Holding_Policy_Type      13202 non-null  float64
#  11  Reco_Policy_Cat          21805 non-null  int64
#  12  Reco_Policy_Premium      21805 non-null  float64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 2.2+ MB

# %%
test_df['Health Indicator'].fillna('X0', inplace = True)
test_df['Holding_Policy_Duration'].fillna(0.0, inplace = True)
test_df['Holding_Policy_Type'].fillna('0', inplace = True)

# %%
test_df['Age'] = (test_df['Upper_Age'] + test_df['Lower_Age'])/2
test_df.drop(['Upper_Age', 'Lower_Age'], axis = 1, inplace = True)

# %%
test_df['Holding_Policy_Duration'] = test_df['Holding_Policy_Duration'].apply(lambda x: 15 if x == '14+' else float(x))
test_df['Holding_Policy_Duration'] = test_df['Holding_Policy_Duration'].apply(lambda x: float(x))

# %%
test_df.info()

# %%
test_df['Is_Spouse'] = test_df['Is_Spouse'].map({'No': 0, 'Yes': 1})

# %%
test_df = pd.get_dummies(test_df, columns = ['Health Indicator'])

# %%
lbl2 = LabelEncoder()
city = lbl2.fit_transform(test_df['City_Code'])
test_df['City_Code'] = city

# %%
test_df = pd.get_dummies(test_df, columns = ['Reco_Insurance_Type'], drop_first = True)

# %%
test_df

# %%
id = test_df.ID
test_df = test_df.drop(['ID'], axis = 1)

# %%
test_df.columns

# %%
test_df = test_df.drop(['Reco_Insurance_Type', 'IS_Spouse'], axis = 1)

# %% [markdown]
# # Model Without City and Region Importance

# %%
# Dropping city and region importance
X1 = dummies.drop(['City_Code', 'Region_Code', 'Response', 'ID'], axis = 1)
y1 = dummies['Response']

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.20, random_state=46)

# %%
X_train

# %%
model=xgb.XGBClassifier(random_state=1,learning_rate=0.01, use_label_encoder = False)
model.fit(X_train, y_train)
model.score(X_test,y_test)

# %%
xgb.plot_importance(model)

# %% [markdown]
# # Customizing the model

# %%
X3 = dummies[['Region_Code', 'City_Code', 'Reco_Policy_Cat', 'Reco_Policy_Premium', 'Holding_Policy_Duration', 'Age', 'Holding_Policy_Type_3.0', 'Health Indicator', 'Holding_Policy_Type_1.0', 'Accomodation_Type_Owned', 'Holding_Policy_Type_4.0']]
y3 = dummies['Response']

# %%
Xt, Xv, yt, yv = train_test_split(X3, y3, test_size = 0.25, random_state = 0)

# %%
dt = xgb.DMatrix(Xt.to_numpy(),label=yt.to_numpy())
dv = xgb.DMatrix(Xv.to_numpy(),label=yv.to_numpy())
params = {
    "eta": 0.2,
    "max_depth": 4,
    "objective": "binary:logistic",
    "silent": 1,
    "base_score": np.mean(yt),
    'n_estimators': 1000,
    "eval_metric": "logloss"
}
model = xgb.train(params, dt, 2000, [(dt, "train"),(dv, "valid")], verbose_eval=200)

# %%
y_pred = model.predict(dv)
y_pred = [round(value) for value in y_pred]
accuracy_score(y_pred, yv)

# %%
xgb.plot_importance(model)

# %%
# city code inclusive
Xt, Xv, yt, yv = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
dt = xgb.DMatrix(Xt.to_numpy(),label=yt.to_numpy())
dv = xgb.DMatrix(Xv.to_numpy(),label=yv.to_numpy())
params = {
    "eta": 0.2,
    "max_depth": 4,
    "objective": "binary:logistic",
    "silent": 1,
    "base_score": np.mean(yt),
    'n_estimators': 1000,
    "eval_metric": "logloss"
}
model = xgb.train(params, dt, 3000, [(dt, "train"),(dv, "valid")], verbose_eval=200)

# %%
y_pred = model.predict(dv)
y_pred

# %%
yv

# %% [markdown]
# # Using Voting Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

log_clf = LogisticRegression(solver="lbfgs", random_state=42)
rnd_clf = RandomForestClassifier(n_estimators=500, random_state=42)
svm_clf = SVC(gamma="scale", random_state=42)


voting_clf = VotingClassifier(
    estimators=[('lr', log_clf), ('rf', rnd_clf), ('svc', svm_clf)],
    voting='hard')
voting_clf.fit(X_train, y_train)

# %%
for clf in (log_clf, rnd_clf, svm_clf, voting_clf):
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(clf.__class__.__name__, accuracy_score(y_test, y_pred))
